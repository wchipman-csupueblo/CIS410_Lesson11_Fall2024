# %%
import pandas as pd

# %%
data = pd.read_csv('gold.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847 entries, 0 to 846
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    847 non-null    object
#  1   Price   847 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.4+ KB

# %%
data.Date = pd.to_datetime(data.Date)
data.head()
# Out:
#         Date  Price
# 0 1950-01-01  34.73
# 1 1950-02-01  34.73
# 2 1950-03-01  34.73
# 3 1950-04-01  34.73
# 4 1950-05-01  34.73

# %%
data.plot(x='Date', y='Price')
# Out:
# <Axes: xlabel='Date'>

# %%
data.set_index('Date', inplace=True)
years = pd.date_range('1950-01-01', '2020-01-01', freq='YS')

# %%
data.reindex(years).head()
# Out:
#             Price
# 1950-01-01  34.73
# 1951-01-01  34.72
# 1952-01-01  34.49
# 1953-01-01  34.88
# 1954-01-01  34.86

# %%
data.reindex(years).plot()
# Out:
# <Axes: >

# %%
data.resample(rule='Q').mean(numeric_only=True).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.resample(rule='Y').mean(numeric_only=True).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.rolling(window=6).mean(numeric_only=True).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.rolling(window=12).mean(numeric_only=True).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.rolling(window=30).mean(numeric_only=True).plot()
# Out:
# <Axes: xlabel='Date'>
